# %% [markdown]
# <a href="https://colab.research.google.com/github/TiamatCod3/tcc-canabidiol/blob/master/Curso_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Relatório de Analise I

# %% [markdown]
# ## Importando a Base de Dados

# %%
# Importando o pandas

import pandas as pd

# %%
# Importando
dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/aluguel.csv', sep = ';')
dados
# Out:
#                           Tipo                Bairro  Quartos  Vagas  Suites  \
# 0                    Quitinete            Copacabana        1      0       0
# 1                         Casa       Jardim Botânico        2      0       1
# 2      Conjunto Comercial/Sala       Barra da Tijuca        0      4       0
# 3                  Apartamento                Centro        1      0       0
# 4                  Apartamento          Higienópolis        1      0       0
# ...                        ...                   ...      ...    ...     ...
# 32955                Quitinete                Centro        0      0       0
# 32956              Apartamento           Jacarepaguá        3      1       2
# 32957              Apartamento  São Francisco Xavier        2      1       0
# 32958              Apartamento                Leblon        2      0       0
# 32959  Conjunto Comercial/Sala                Centro        0      0       0
#
#        Area   Valor  Condominio    IPTU
# ...

# %% [markdown]
# ## Informações Gerais

# %%
print(dados.dtypes)
print(type(dados))
# Out:
# Tipo           object
# Bairro         object
# Quartos         int64
# Vagas           int64
# Suites          int64
# Area            int64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object
# <class 'pandas.core.frame.DataFrame'>

# %%
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
#Cria um dataframe com os tipos de dados de cada coluna e põe como titulo Tipo de Dados
tiposDeDados = pd.DataFrame(dados.dtypes, columns=['Tipo de Dados'])
tiposDeDados
# Out:
#            Tipo de Dados
# Tipo              object
# Bairro            object
# Quartos            int64
# Vagas              int64
# Suites             int64
# Area               int64
# Valor            float64
# Condominio       float64
# IPTU             float64

# %%
tiposDeDados.columns.name = 'Colunas'
tiposDeDados
# Out:
# Colunas    Tipo de Dados
# Tipo              object
# Bairro            object
# Quartos            int64
# Vagas              int64
# Suites             int64
# Area               int64
# Valor            float64
# Condominio       float64
# IPTU             float64

# %%
#Numero de linhas e de colunas
dados.shape
#Permite usar [] para indicar o indice
# Out:
# (32960, 9)

# %%
print("A base possui {} linhas (registros) e {} colunas (variaveis)" .format(dados.shape[0], dados.shape[1]))
# Out:
# A base possui 32960 linhas (registros) e 9 colunas (variaveis)

# %% [markdown]
# ## Extraindo os Tipos de Imoveis

# %%
dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/aluguel.csv', sep = ';')

# %%
#Mostra os valores da coluna

dados['Tipo']

#Ou dados.Tipo
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
#Cria uma Series com a coluna desejada

tipoImovel = dados['Tipo']
tipoImovel
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %%
#Mostra os valores unicos

tipoImovel.drop_duplicates()
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %%
# inplace substitui a Series anterior pela nova, que contem apenas os valores unicos (por default o valor vem como false no metodo)

tipoImovel.drop_duplicates(inplace = True)
tipoImovel
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %% [markdown]
# ## Organizando a Visualização

# %%
# Transforma a Series em um DataFrame

tipoImovel = pd.DataFrame(tipoImovel)
tipoImovel
# Out:
#                               Tipo
# 0                        Quitinete
# 1                             Casa
# 2          Conjunto Comercial/Sala
# 3                      Apartamento
# 7               Casa de Condomínio
# 16                  Prédio Inteiro
# 17                            Flat
# 29                      Loja/Salão
# 80         Galpão/Depósito/Armazém
# 83                  Casa Comercial
# 117                   Casa de Vila
# 159                 Terreno Padrão
# 207                    Box/Garagem
# 347                           Loft
# 589    Loja Shopping/ Ct Comercial
# 2157                       Chácara
# 3354         Loteamento/Condomínio
# 4379                         Sítio
# 4721                 Pousada/Chalé
# 6983                        Studio
# 9687                         Hotel
# 23614                    Indústria

# %%
#Mostra os indexes

tipoImovel.index
# Out:
# Int64Index([    0,     1,     2,     3,     7,    16,    17,    29,    80,
#                83,   117,   159,   207,   347,   589,  2157,  3354,  4379,
#              4721,  6983,  9687, 23614],
#            dtype='int64')

# %%
# Analogo ao len()

tipoImovel.shape[0]
# Out:
# 22

# %%
# Altera os indexes pro tamanho do DataFrame

tipoImovel.index = range(tipoImovel.shape[0])
tipoImovel
# Out:
#                            Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
tipoImovel.index
# Out:
# RangeIndex(start=0, stop=22, step=1)

# %%
tipoImovel
# Out:
#                            Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
# Renomeia a Coluna

tipoImovel.columns.name = 'ID'
tipoImovel
# Out:
# ID                         Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %% [markdown]
# ## Selecionando Apenas um tipo (Imoveis Residenciais)

# %%
# Importa a base denovo

dados = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/aluguel.csv', sep = ';')
dados.head(10)
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#      Valor  Condominio    IPTU
# 0   1700.0       500.0    60.0
# 1   7000.0         NaN     NaN
# 2   5200.0      4020.0  1111.0
# ...

# %%
# Cria uma lista com os valores sem duplicatas

list(dados['Tipo'].drop_duplicates())

# %%
# Seleciona e guarda os valores que interessa em outra lista

residencial = ['Quitinete',
'Casa',
 'Apartamento',
 'Casa de Condomínio', 
 'Casa de Vila', 
 'Chácara',
 'Loteamento/Condomínio',
 'Sítio',
 ]

residencial

# %%
# Cria uma Series booleana retornando true na coluna onde for encontrado algum valor que estivesse contido na lista

selecao = dados['Tipo'].isin(residencial)
selecao
# Out:
# 0         True
# 1         True
# 2        False
# 3         True
# 4         True
#          ...
# 32955     True
# 32956     True
# 32957     True
# 32958     True
# 32959    False
# Name: Tipo, Length: 32960, dtype: bool

# %%
# Cria um DF com apenas as linhas True da seleçao

dadosResidenciais = dados[selecao]
dadosResidenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
#Verifica os tipos unicos para conferir

list(dadosResidenciais['Tipo'].drop_duplicates())
# Out:
# ['Quitinete',
#  'Casa',
#  'Apartamento',
#  'Casa de Condomínio',
#  'Casa de Vila',
#  'Chácara',
#  'Loteamento/Condomínio',
#  'Sítio']

# %%
# Reconstroi o index

dadosResidenciais.index = range(dadosResidenciais.shape[0])
dadosResidenciais
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22591  Apartamento                 Méier        2      0       0    70
# 22592    Quitinete                Centro        0      0       0    27
# 22593  Apartamento           Jacarepaguá        3      1       2    78
# 22594  Apartamento  São Francisco Xavier        2      1       0    48
# 22595  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %% [markdown]
# ## Exportando a Base de Dados

# %%
#Exportando em CSV

dadosResidenciais.to_csv('/content/drive/MyDrive/Colab Notebooks/data/aluguelResidencial.csv', sep =';')

# %%
# Testando o import

dadosResidenciais2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/aluguelResidencial.csv', sep = ';')
dadosResidenciais2
# Out:
#        Unnamed: 0         Tipo                Bairro  Quartos  Vagas  Suites  \
# 0               0    Quitinete            Copacabana        1      0       0
# 1               1         Casa       Jardim Botânico        2      0       1
# 2               2  Apartamento                Centro        1      0       0
# 3               3  Apartamento          Higienópolis        1      0       0
# 4               4  Apartamento          Vista Alegre        3      1       0
# ...           ...          ...                   ...      ...    ...     ...
# 22591       22591  Apartamento                 Méier        2      0       0
# 22592       22592    Quitinete                Centro        0      0       0
# 22593       22593  Apartamento           Jacarepaguá        3      1       2
# 22594       22594  Apartamento  São Francisco Xavier        2      1       0
# 22595       22595  Apartamento                Leblon        2      0       0
#
#        Area   Valor  Condominio  IPTU
# ...

# %%
# Exportando sem o index

dadosResidenciais.to_csv('/content/drive/MyDrive/Colab Notebooks/data/aluguelResidencial.csv', sep =';', index = False)

# %%
# Testando o import sem o index

dadosResidenciais2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/data/aluguelResidencial.csv', sep = ';')
dadosResidenciais2
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 2      Apartamento                Centro        1      0       0    15
# 3      Apartamento          Higienópolis        1      0       0    48
# 4      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 22591  Apartamento                 Méier        2      0       0    70
# 22592    Quitinete                Centro        0      0       0    27
# 22593  Apartamento           Jacarepaguá        3      1       2    78
# 22594  Apartamento  São Francisco Xavier        2      1       0    48
# 22595  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...
